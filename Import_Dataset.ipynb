# %%
# cette cellule Monte le disque google drive
# il faut Copier coller le code demandé dans le lien

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Remplacer les valeurs par les valeurs du token kaggle
#ce fichier kaggle.json peut s ouvrir avec un editeur de texte comme wordpad
user = "toto"
key = "a905d6e3445d4f8834d6e8b0883fe1ac"

# %%
#import des librairies
import os
if '.kaggle' not in os.listdir('/root'):
    # !mkdir ~/.kaggle
# !touch /root/.kaggle/kaggle.json
# !chmod 666 /root/.kaggle/kaggle.json
with open('/root/.kaggle/kaggle.json', 'w') as f:
    f.write('{"username":"%s","key":"%s"}' % (user, key))
# !chmod 600 /root/.kaggle/kaggle.json
! pip install kaggle
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
#Creer le repertoire Projet_Plante si il n'existe pas
os.system("mkdir -m 700 /content/drive/MyDrive/Projet_Plante")

# %%
#Lister les dataset qui contiennent les mots New-Plant-Diseases-Dataset
# !kaggle datasets list -s New-Plant-Diseases-Dataset

# %%
#telecharger le dataset choisi
# !kaggle datasets download vipoooool/new-plant-diseases-dataset

# %%
#dezipper
# !unzip new-plant-diseases-dataset.zip

# %%
#copier sur drive, n'ecrase pas les fichiers deja presents
# !cp -vnpr /content/'New Plant Diseases Dataset(Augmented)' /content/drive/MyDrive/Projet_Plante
